# %% [markdown]
# <div style="
#     text-align: center;
#     max-width: 600px;
#     margin: 0 auto;
#     background:
#     rgba(62, 128, 234, 1);
#     color: white;
#     padding: 12px;
#     border-radius: 4px;
# ">
#   <h3> ★ crime ★ </h3>
#   <p> This notebook is a helper notebook to streamline the mapping of crime data points and segment scoring.</p>
#   <p> It uses the preset buffers in new_crime_edge_mapping.ipynb and crime_scoring.ipynb</p>
#
# </div>

# %%
import pandas as pd

# %%
# %run ../crime/edge_mapping.ipynb
# %run ../crime/scoring.ipynb

# %%
def cbs_to_df(edges):
    edges_upd, mapping = cb_mapping(edges)

    return cb_scoring(edges_upd, mapping)
